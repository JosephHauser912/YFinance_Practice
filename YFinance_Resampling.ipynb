# %%
# %run YFinance_Load_Data.ipynb
# %run YFinance_Line_Plots.ipynb
# Out:
# [*********************100%%**********************]  2 of 2 completed
# [*********************100%%**********************]  2 of 2 completed
# [*********************100%%**********************]  2 of 2 completed
# [*********************100%%**********************]  2 of 2 completed
# [*********************100%%**********************]  2 of 2 completed

# %%
(raw
.iloc[:,::2]
 .pipe(fix_cols)
 .Close
)
#daily values
# Out:
# Date
# 2010-01-04     7.643214
# 2010-01-05     7.656429
# 2010-01-06     7.534643
# 2010-01-07     7.520714
# 2010-01-08     7.570714
#                 ...
# 2019-12-23    71.000000
# 2019-12-24    71.067497
# 2019-12-26    72.477501
# 2019-12-27    72.449997
# 2019-12-30    72.879997
# Name: Close, Length: 2515, dtype: float64

# %%
(raw
.iloc[:,::2]
 .pipe(fix_cols)
 .resample('M') #offset alias - a string to notify pandas we want to aggregate at the month level
 .Close
) #will return series

# %%
(raw
.iloc[:,::2]
 .pipe(fix_cols)
 .resample('M') #offset alias - a string to notify pandas we want to aggregate at the month level
 .Close
 .mean() #need this aggregation method to display #returns the mean for each month
)
# Out:
# Date
# 2010-01-31     7.418402
# 2010-02-28     7.099850
# 2010-03-31     7.978960
# 2010-04-30     8.969592
# 2010-05-31     8.980768
#                 ...
# 2019-08-31    51.239432
# 2019-09-30    54.498750
# 2019-10-31    58.821630
# 2019-11-30    65.630126
# 2019-12-31    68.917374
# Freq: M, Name: Close, Length: 120, dtype: float64

# %%
(raw
.iloc[:,::2]
 .pipe(fix_cols)
 .resample('2M') #offset alias - a string to notify pandas we want to aggregate at the 2month level
 .Close
 .mean() #need this aggregation method to display #returns the mean for each month
)
# Out:
# Date
# 2010-01-31     7.418402
# 2010-03-31     7.581267
# 2010-05-31     8.975044
# 2010-07-31     9.218563
# 2010-09-30     9.368754
#                 ...
# 2019-05-31    48.946861
# 2019-07-31    49.846072
# 2019-09-30    52.791488
# 2019-11-30    61.988372
# 2020-01-31    68.917374
# Freq: 2M, Name: Close, Length: 61, dtype: float64

# %%
(raw
.iloc[:,::2]
 .pipe(fix_cols)
 .resample('M') #offset alias - a string to notify pandas we want to aggregate at the month level
 .Close
 .mean() #need this aggregation method to display #returns the mean for each month
 .plot()
)
